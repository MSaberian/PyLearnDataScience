# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
apple_width = np.random.normal(6,.5,400)
apple_henght = np.random.normal(6,.5,400)

# %%
plt.scatter(apple_width, apple_henght, color='red')
plt.show()

# %%
banana_width = np.random.normal(4,.5,400)
banana_henght = np.random.normal(8,1,400)

# %%
plt.scatter(banana_width, banana_henght, color='yellow')
plt.scatter(apple_width, apple_henght, color='red')
plt.show()
